# %%
import numpy as np
import matplotlib.pyplot as plt

from simulator.model import AirportModel

# %%
airport = AirportModel(verbose=False)
print(airport)
for _ in range(500):
    airport.step()
#     airport.plot_position_history()
# print(f"{len(airport.schedule.agents)} planes left in stands")
# print(airport.stands)

airport.plot_position_history()
# Out:
# <simulator.model.AirportModel object at 0x114a95860>

# %%
airport.datacollector.get_model_vars_dataframe().max()
# Out:
# number_planes                 NaN
# planes_in_line              392.0
# planes_taxiing_to_stand       8.0
# planes_at_stand               5.0
# planes_served_at_stand_1      2.0
# planes_served_at_stand_2      8.0
# planes_served_at_stand_3     17.0
# planes_served_at_stand_4      1.0
# planes_served_at_stand_5      2.0
# planes_served_at_stand_6     10.0
# planes_served_at_stand_7     17.0
# dtype: float64

# %%
airport.datacollector.get_agent_vars_dataframe()
# Out:
#               tick_count             state   x  y is_at_stand  \
# Step AgentID
# 1    0                 1  taxiing_to_stand  10  1        None
# 2    0                 2  taxiing_to_stand   9  1        None
#      1                 1  taxiing_to_stand  11  0        None
# 3    0                 3  taxiing_to_stand   9  2        None
#      1                 2  taxiing_to_stand  11  1        None
#      2                 1  taxiing_to_stand   9  0        None
# 4    0                 4  taxiing_to_stand   9  3        None
#      1                 3  taxiing_to_stand  11  2        None
#      2                 2  taxiing_to_stand   8  0        None
# 5    0                 5  taxiing_to_stand   8  3        None
#      1                 4  taxiing_to_stand  12  2        None
#      2                 3  taxiing_to_stand   8  1        None
#      3                 1  taxiing_to_stand   9  0        None
# 6    0                 6  taxiing_to_stand   8  4        None
#      1                 5  taxiing_to_stand  13  2        None
#      2                 4  taxiing_to_stand   7  1        None
#      3                 2  taxiing_to_stand   9  1        None
#      4                 1  taxiing_to_stand  10  1        None
# 7    0                 7  taxiing_to_stand   8  5        None
#      1                 6  taxiing_to_stand  13  3        None
#      2                 5  taxiing_to_stand   7  2        None
#      3                 3  taxiing_to_stand   8  1        None
#      4                 2  taxiing_to_stand  11  1        None
#      5                 1  taxiing_to_stand  11  0        None
# 8    0                 8  taxiing_to_stand   8  6        None
#      1                 7  taxiing_to_stand  14  3        None
#      2                 6  taxiing_to_stand   7  3        None
#      3                 4  taxiing_to_stand   8  2        None
#      4                 3  taxiing_to_stand  12  1        None
#      5                 2  taxiing_to_stand  12  0        None
# ...                  ...               ...  .. ..         ...
# 49   15               32           in_line  10  0        None
#      16               31           in_line  10  0        None
#      17               30           in_line  10  0        None
#      18               28           in_line  10  0        None
#      19               27           in_line  10  0        None
#      20               26           in_line  10  0        None
#      21               25           in_line  10  0        None
#      22               24           in_line  10  0        None
#      23               23           in_line  10  0        None
#      24               22           in_line  10  0        None
#      25               21           in_line  10  0        None
#      26               20           in_line  10  0        None
#      27               19           in_line  10  0        None
#      28               18           in_line  10  0        None
#      29               17           in_line  10  0        None
#      30               16           in_line  10  0        None
#      31               15           in_line  10  0        None
#      32               14           in_line  10  0        None
#      33               13           in_line  10  0        None
#      34               12           in_line  10  0        None
#      35               11           in_line  10  0        None
#      36               10           in_line  10  0        None
#      37                9           in_line  10  0        None
#      38                8           in_line  10  0        None
#      39                7           in_line  10  0        None
#      40                5           in_line  10  0        None
#      41                4           in_line  10  0        None
#      42                3           in_line  10  0        None
#      43                2           in_line  10  0        None
#      44                1           in_line  10  0        None
#
#               unloading_time_when_at_stand
# Step AgentID
# 1    0                                  22
# 2    0                                  22
#      1                                  26
# 3    0                                  22
#      1                                  26
#      2                                  30
# 4    0                                  22
#      1                                  26
#      2                                  30
# 5    0                                  22
#      1                                  26
#      2                                  30
#      3                                  28
# 6    0                                  22
#      1                                  26
#      2                                  30
#      3                                  28
#      4                                  29
# 7    0                                  22
#      1                                  26
#      2                                  30
#      3                                  28
#      4                                  29
#      5                                  26
# 8    0                                  22
#      1                                  26
#      2                                  30
#      3                                  28
#      4                                  29
#      5                                  26
# ...                                    ...
# 49   15                                 28
#      16                                 30
#      17                                 20
#      18                                 22
#      19                                 22
#      20                                 30
#      21                                 27
#      22                                 24
#      23                                 29
#      24                                 22
#      25                                 24
#      26                                 23
#      27                                 29
#      28                                 28
#      29                                 26
#      30                                 23
#      31                                 27
#      32                                 26
#      33                                 30
#      34                                 20
#      35                                 24
#      36                                 24
#      37                                 20
#      38                                 30
#      39                                 25
#      40                                 28
#      41                                 29
#      42                                 22
#      43                                 30
#      44                                 20
#
# [1098 rows x 6 columns]

# %%
airport = AirportModel(verbose=False)

for _ in range(50):
    airport.step()

airport.plot_position_history()
# Out:
# There is at least one open
# There is at least one open
# There is at least one open
# There is at least one open
# There is at least one open
# There is at least one open
# There is at least one open
# There is at least one open
# There is at least one open
