# %%
import numpy as np
import matplotlib.pyplot as plt

from simulator.model import AirportModel

# %%
airport = AirportModel(3, verbose=False)
print(airport)
for _ in range(25):
    airport.step()
print(f"{len(airport.schedule.agents)} planes left in stands")
print(airport.stands)
# Out:
# <simulator.model.AirportModel object at 0x11c2297f0>
# 3 planes left in stands
# {0: <Stand 0 type 1: [None, None, None], type 2: [None, None, None, None]>, 1: <Stand 1 type 1: [None, None, None], type 2: [None, None, None, None]>, 2: <Stand 2 type 1: [None, None, None], type 2: [None, None, None, None]>, 3: <Stand 3 type 1: [None, None, None], type 2: [None, None, None, None]>, 4: <Stand 4 type 1: [None, None, None], type 2: [None, None, None, None]>, 5: <Stand 5 type 1: [None, None, None], type 2: [None, None, None, None]>, 6: <Stand 6 type 1: [None, None, None], type 2: [None, None, None, None]>}

# %%
airport.plot_position_history()

# %%
df.plot()
plt.show()
airport.plot_positions()
plt.show()
